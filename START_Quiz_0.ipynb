# %%
import pandas as pd
import seaborn as sns
# We need to import the functions from the quiz_0_answer_sheet.py file.
# You will write the functions in that file, import them and use them here.
import quiz_0_answer_sheet

# You coudl also do:
# from quiz_0_answer_sheet import numberAdder, vowelsInString
# This would alllow you to use the names directly without the module prefix.
# This is shown in the test harnes file.

# %% [markdown]
# # Quiz 0 - Example
#
# This is an example a a completed quiz, so you can see all of the parts, especially the test harness, working.

# %% [markdown]
# ### Load Data
#
# You'll often/normally have a section to load data near the start. Parts of this will likely be labeled as "Do not change", that stuff is intended to get you to a uniform starting point. After that, you may need to modify the code and data.

# %%
# Load the data
# Don't change this part.
df = pd.read_csv("LabourTrainingEvaluationData.csv")
df["target"] = df["Eduacation"]
df.drop(columns=["Eduacation"], inplace=True)
df.head()
# Out:
#    Age      Race         Hisp MaritalStatus  Nodeg  Earnings_1974  \
# 0   45  NotBlack  NotHispanic       Married      1      21516.670
# 1   21  NotBlack  NotHispanic    NotMarried      0       3175.971
# 2   38  NotBlack  NotHispanic       Married      0      23039.020
# 3   48  NotBlack  NotHispanic       Married      1      24994.370
# 4   18  NotBlack  NotHispanic       Married      1       1669.295
#
#    Earnings_1975  Earnings_1978              target
# 0      25243.550      25564.670  LessThanHighSchool
# 1       5852.565      13496.080        Intermediate
# 2      25130.760      25564.670          HighSchool
# 3      25243.550      25564.670  LessThanHighSchool
# 4      10727.610       9860.869  LessThanHighSchool

# %%
df.describe()
# Out:
#                 Age         Nodeg  Earnings_1974  Earnings_1975  Earnings_1978
# count  15992.000000  15992.000000   15992.000000   15992.000000   15992.000000
# mean      33.225238      0.295835   14016.800304   13650.803376   14846.659673
# std       11.045216      0.456432    9569.795893    9270.403225    9647.391524
# min       16.000000      0.000000       0.000000       0.000000       0.000000
# 25%       24.000000      0.000000    4403.452250    4398.823000    5669.298000
# 50%       31.000000      0.000000   15123.580000   14557.110000   16421.975000
# 75%       42.000000      1.000000   23584.180000   22923.737500   25564.670000
# max       55.000000      1.000000   25862.320000   25243.550000   25564.670000

# %% [markdown]
# ## Question 1
#
# Each question will ask you to do some stuff. It might involve writing code in the notebook, or writing a function in the answer sheet file, so please read carefully. Programming is excessively picky, so be sure to follow the instructions exactly.
#
# In this section:
# <ol>
# <li>Write a function in the quiz_0_answer_sheet.py file called numberAdder that takes two numbers as input and returns their sum.</li>
# <li>Use that function to add a column to the dataframe of "Total Earnings", which is a sum of the three earnings columns.</li>
# <li>Show a visualization of the Total Earnings column distribution, note any interesting features.</li>
# </ol>
#
# The automated testing part will check the functions, by calling them and checking the results. I will read your notebook to see your analysis and visualizations, <b>so please make the notebooks clear and easy to read - the point of these files is to make it easy to communicate your work.</b> This is similar to real life settings, it is normal to have the 'working' bits of code automatically tested to ensure that things work.

# %%
# Create total earnings column
df["sum_temp"] = quiz_0_answer_sheet.numberAdder(df["Earnings_1974"], df["Earnings_1975"])
df["total_earnings"] = quiz_0_answer_sheet.numberAdder(df["sum_temp"], df["Earnings_1978"])
df.drop(columns=["sum_temp"], inplace=True)
df.head()
# Out:
#    Age      Race         Hisp MaritalStatus  Nodeg  Earnings_1974  \
# 0   45  NotBlack  NotHispanic       Married      1      21516.670
# 1   21  NotBlack  NotHispanic    NotMarried      0       3175.971
# 2   38  NotBlack  NotHispanic       Married      0      23039.020
# 3   48  NotBlack  NotHispanic       Married      1      24994.370
# 4   18  NotBlack  NotHispanic       Married      1       1669.295
#
#    Earnings_1975  Earnings_1978              target  total_earnings
# 0      25243.550      25564.670  LessThanHighSchool       72324.890
# 1       5852.565      13496.080        Intermediate       22524.616
# 2      25130.760      25564.670          HighSchool       73734.450
# 3      25243.550      25564.670  LessThanHighSchool       75802.590
# 4      10727.610       9860.869  LessThanHighSchool       22257.774

# %%
# Visualization
sns.histplot(data=df, x="total_earnings", kde=True)
# Out:
# <Axes: xlabel='total_earnings', ylabel='Count'>

# %% [markdown]
# ## Question 2
#
# In this section:
# <ol>
# <li>Write a function in the quiz_0_answer_sheet.py file called vowelsInString that takes a string as input and returns the total number of vowels in the string.</li>
# <li>Use that function to create a new column in the dataframe that contains the number of vowels in the four text columns.</li>
# <li>Show a visualization of the number of vowels in the text columns, thinking about how to best show the information.</li>
# </ol>
#
# <b>Remember, please make the notebooks clear and easy to read - the point of these files is to make it easy to communicate your work.</b>

# %%
# Do some stuff with text columns

# %% [markdown]
# ## Checking Pytest on Github
#
# You can see the results of the automated tests by clicking on the "Actions" tab at the top of the Github repository page. There will only be one or maybe two workflows, the testing one is likely called run-autgrading-tests, or similar. Click on that, then click on the most recent run (at the top of the list). You should see a green check mark if everything passed, or a red X if something failed. Click on the red X to see more details.
#
# ![pytest](images/pytest.png)
#
# You can also run the tests locally, just open a temrinal in vs code and run the command `pytest`. Note that your terminal needs to have the correct python environment activated - the one with pytest installed. If you only have one, this isn't a big deal, but if you have multiple python environments, you may need to type 'conda activate <env name>' first.
#
# ![pytest_local](images/terminal_pytest.png)
